# %% [markdown]
# # Yelp Data Challenge
#
# ## Part IV - Restaurant Recommender

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
plt.style.use("ggplot")

# %%
df = pd.read_csv('yelp_dataset/last_3_years_restaurant_reviews.csv')

# %%
df.head()
# Out:
#    Unnamed: 0             business_id                  name  \
# 0           1  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 1           6  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 2          14  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 3          15  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 4          27  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
#
#                                categories  avg_stars  cool        date  funny  \
# 0  Steakhouses, Restaurants, Cajun/Creole        4.0     0  2017-02-14      0
# 1  Steakhouses, Restaurants, Cajun/Creole        4.0     0  2017-12-04      0
# 2  Steakhouses, Restaurants, Cajun/Creole        4.0     0  2016-08-22      1
# 3  Steakhouses, Restaurants, Cajun/Creole        4.0     0  2016-09-13      0
# 4  Steakhouses, Restaurants, Cajun/Creole        4.0     0  2016-08-08      0
#
#                 review_id  stars  \
# 0  VETXTwMw6qxzOVDlXfe6Tg      5
# 1  S8-8uZ7fa5YbjnEtaW15ng      5
# 2  1nK5w0VNfDlnR3bOz13dJQ      5
# 3  N1Z93BthdJ7FT2p5S22jIA      3
# 4  ir-EVhHyWna7KqYWtj660g      5
#
#                                                 text  useful  \
# 0  went for dinner tonight. Amazing my husband ha...       0
# 1  This was an amazing dinning experience! ORDER ...       0
# 2  My husband and I went there for lunch on a Sat...       1
# 3  Went for a nice anniversary dinner. Researched...       0
# 4  Hands down the best meal and service I have ev...       0
#
#                   user_id
# 0  ymlnR8UeFvB4FZL56tCZsA
# 1  9pSSL6X6lFpY3FCRLEH3og
# 2  gm8nNoA3uB4In5o_Hxpq3g
# 3  CEtidlXNyQzgJSdF1ubPFw
# 4  9_BhDyzJYf2JwTD9TyXJ4g

# %% [markdown]
# ## 1. Clean data and get rating data

# %% [markdown]
# #### Select relevant columns in the original dataframe

# %%
# Get business_id, user_id, stars for recommender
columns_selected = [u'business_id',u'user_id',u'stars']
df_recommend = df[columns_selected]

# %%
df_recommend.head(10)
# Out:
#               business_id                 user_id  stars
# 0  --9e1ONYQuAa-CB_Rrw7Tw  ymlnR8UeFvB4FZL56tCZsA      5
# 1  --9e1ONYQuAa-CB_Rrw7Tw  9pSSL6X6lFpY3FCRLEH3og      5
# 2  --9e1ONYQuAa-CB_Rrw7Tw  gm8nNoA3uB4In5o_Hxpq3g      5
# 3  --9e1ONYQuAa-CB_Rrw7Tw  CEtidlXNyQzgJSdF1ubPFw      3
# 4  --9e1ONYQuAa-CB_Rrw7Tw  9_BhDyzJYf2JwTD9TyXJ4g      5
# 5  --9e1ONYQuAa-CB_Rrw7Tw  cZVQGCZ_fHtTdfiyGVJPdg      5
# 6  --9e1ONYQuAa-CB_Rrw7Tw  rhP3yu4Sxpj9OXgeY0VpLg      5
# 7  --9e1ONYQuAa-CB_Rrw7Tw  AZcrPTUbzOEvy-gr-2jZCw      5
# 8  --9e1ONYQuAa-CB_Rrw7Tw  li2cBZl60vgqihDJJG7jeA      2
# 9  --9e1ONYQuAa-CB_Rrw7Tw  GQWk8vgYGlN9hp0XP0V05w      5

# %%
df_recommend['stars'].value_counts()
# Out:
# 5    269295
# 4    114025
# 1     71878
# 3     59248
# 2     44441
# Name: stars, dtype: int64

# %%
df_recommend['business_id'].nunique()
# Out:
# 4929

# %%
user_reviews = df_recommend.groupby('user_id').business_id.nunique()

# %%
user_reviews.describe()
# Out:
# count    249410.000000
# mean          2.240836
# std           4.584291
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max         652.000000
# Name: business_id, dtype: float64

# %%
user_reviews.quantile(q=0.95)
# Out:
# 6.0

# %% [markdown]
# #### There are many users that haven't given many reviews, exclude these users from the item-item similarity recommender
#
# **Q**: How do we recommend to these users anyways?

# %%
# To be implemented
df_copy = df.groupby(['user_id']).size().reset_index(name='counts')

# %%
counts_condition = df_copy['counts'] >= 66
select_user_id = set(df_copy[counts_condition]['user_id'].values)

# %%
def keep(row):
    if row['user_id'] in select_user_id:
        val = 1
    else:
        val = 0
    return val
df['keep'] = df.apply(keep,axis = 1)

# %%
condition = df['keep'] == 1
df_final = df[condition]

# %%
df_final.shape
# Out:
# (18765, 14)

# %%
df.shape
# Out:
# (558887, 14)

# %%
df_final.reset_index()
# Out:
#         index  Unnamed: 0             business_id                        name  \
# 0          67         321  --9e1ONYQuAa-CB_Rrw7Tw        Delmonico Steakhouse
# 1          96         417  --9e1ONYQuAa-CB_Rrw7Tw        Delmonico Steakhouse
# 2         221         788  --9e1ONYQuAa-CB_Rrw7Tw        Delmonico Steakhouse
# 3         228         813  --9e1ONYQuAa-CB_Rrw7Tw        Delmonico Steakhouse
# 4         254         880  --9e1ONYQuAa-CB_Rrw7Tw        Delmonico Steakhouse
# 5         292         999  --9e1ONYQuAa-CB_Rrw7Tw        Delmonico Steakhouse
# 6         323        1092  --9e1ONYQuAa-CB_Rrw7Tw        Delmonico Steakhouse
# 7         403        1341  --9e1ONYQuAa-CB_Rrw7Tw        Delmonico Steakhouse
# 8         457        1509  --9e1ONYQuAa-CB_Rrw7Tw        Delmonico Steakhouse
# 9         575        1665  -1m9o3vGRA8IBPNvNqKLmA  Bavette's Steakhouse & Bar
# 10        576        1666  -1m9o3vGRA8IBPNvNqKLmA  Bavette's Steakhouse & Bar
# 11        609        1699  -1m9o3vGRA8IBPNvNqKLmA  Bavette's Steakhouse & Bar
# 12        703        2119  -3zffZUHoY8bQjGfPSoBKQ                Michael Mina
# 13        723        2194  -3zffZUHoY8bQjGfPSoBKQ                Michael Mina
# 14        753        2275  -3zffZUHoY8bQjGfPSoBKQ                Michael Mina
# 15        767        2310  -3zffZUHoY8bQjGfPSoBKQ                Michael Mina
# 16        773        2333  -3zffZUHoY8bQjGfPSoBKQ                Michael Mina
# 17        802        2420  -8R_-EkGpUhBk55K9Dd4mg    Sin City Thai Restaurant
# 18        813        2453  -8R_-EkGpUhBk55K9Dd4mg    Sin City Thai Restaurant
# 19        817        2460  -8R_-EkGpUhBk55K9Dd4mg    Sin City Thai Restaurant
# 20        822        2468  -8R_-EkGpUhBk55K9Dd4mg    Sin City Thai Restaurant
# 21        844        2508  -8R_-EkGpUhBk55K9Dd4mg    Sin City Thai Restaurant
# 22        961        2766  -AD5PiuJHgdUcAK-Vxao2A                 Smashburger
# 23        995        2911  -AD5PiuJHgdUcAK-Vxao2A                 Smashburger
# 24        996        2920  -AD5PiuJHgdUcAK-Vxao2A                 Smashburger
# 1                 Steakhouses, Restaurants, Cajun/Creole        4.0    37
# 2                 Steakhouses, Restaurants, Cajun/Creole        4.0     1
# 3                 Steakhouses, Restaurants, Cajun/Creole        4.0     0
# 4                 Steakhouses, Restaurants, Cajun/Creole        4.0     0
# 5                 Steakhouses, Restaurants, Cajun/Creole        4.0     0
# 6                 Steakhouses, Restaurants, Cajun/Creole        4.0     1
# 7                 Steakhouses, Restaurants, Cajun/Creole        4.0     5
# 8                 Steakhouses, Restaurants, Cajun/Creole        4.0     6
# 9      African, Restaurants, Bars, American (New), Co...        4.5     2
# 10     African, Restaurants, Bars, American (New), Co...        4.5     5
# 11     African, Restaurants, Bars, American (New), Co...        4.5    26
# 12     Nightlife, American (New), Bars, Seafood, Rest...        4.0     0
# 13     Nightlife, American (New), Bars, Seafood, Rest...        4.0    10
# 14     Nightlife, American (New), Bars, Seafood, Rest...        4.0     3
# 15     Nightlife, American (New), Bars, Seafood, Rest...        4.0    37
# 16     Nightlife, American (New), Bars, Seafood, Rest...        4.0    13
# 17                                     Restaurants, Thai        3.5     0
# 18                                     Restaurants, Thai        3.5    26
# 19                                     Restaurants, Thai        3.5     2
# 20                                     Restaurants, Thai        3.5     4
# 21                                     Restaurants, Thai        3.5     1
# 22                                  Restaurants, Burgers        3.5     0
# 23                                  Restaurants, Burgers        3.5     2
# 24                                  Restaurants, Burgers        3.5     2
# 25                                  Restaurants, Burgers        3.5    17
# 26     Sushi Bars, Asian Fusion, Restaurants, Japanes...        4.0     0
# 27     Sushi Bars, Asian Fusion, Restaurants, Japanes...        4.0    25
# 28     Sushi Bars, Asian Fusion, Restaurants, Japanes...        4.0     1
# 29     Sushi Bars, Asian Fusion, Restaurants, Japanes...        4.0     1
# ...                                                  ...        ...   ...
# 18735  Vietnamese, Delis, Sandwiches, Asian Fusion, R...        4.0     4
# 18736  Vietnamese, Delis, Sandwiches, Asian Fusion, R...        4.0     0
# 18737  Vietnamese, Delis, Sandwiches, Asian Fusion, R...        4.0     1
# 18738  Vietnamese, Delis, Sandwiches, Asian Fusion, R...        4.0     2
# 18739  Vietnamese, Delis, Sandwiches, Asian Fusion, R...        4.0     5
# 18740  Vietnamese, Delis, Sandwiches, Asian Fusion, R...        4.0     4
# 18741  Vietnamese, Delis, Sandwiches, Asian Fusion, R...        4.0     0
# 18742      Tapas Bars, Sushi Bars, Japanese, Restaurants        3.5     4
# 18743      Tapas Bars, Sushi Bars, Japanese, Restaurants        3.5     7
# 18744                   Vegetarian, Mexican, Restaurants        4.0    13
# 18745                   Vegetarian, Mexican, Restaurants        4.0     2
# 18746                   Vegetarian, Mexican, Restaurants        4.0     4
# 18747                   Vegetarian, Mexican, Restaurants        4.0     2
# 18748                   Vegetarian, Mexican, Restaurants        4.0     0
# 18749                   Vegetarian, Mexican, Restaurants        4.0     0
# 18750                   Vegetarian, Mexican, Restaurants        4.0     0
# 18751                   Vegetarian, Mexican, Restaurants        4.0     0
# 18752                   Vegetarian, Mexican, Restaurants        4.0     0
# 18753                   Vegetarian, Mexican, Restaurants        4.0     2
# 18754                   Vegetarian, Mexican, Restaurants        4.0     8
# 18755                   Vegetarian, Mexican, Restaurants        4.0     0
# 23     This place is amazing and the staff will go ou...       1
# 24     Smashburger makes a good burger. I've only bee...       1
# 25     For some reason I feel like Smashburger is hea...      18
# 26     I really enjoyed the karage chicken here. I re...       0
# 27     I am most grateful that I no longer have to dr...      32
# 28     The reviews for Ichi were all over the place, ...       1
# 29     Considering it's the only ramen I know of in t...       0
# ...                                                  ...     ...
# 18735  I had heard that this palace is the best in Ve...       5
# 18736  Ordered the banh cuon here. It was pre made an...       0
# 18737  Let me just tell u ... this place is great.. s...       1
# 18738  I actually like this place and think that the ...       3
# 18739  If you're looking for a good banh mi shop on S...       4
# 18740  Small little shop next to Sunfood market. It's...       4
# 18741  I've eaten a lot of banh mi in Vegas, which ha...       0
# 18742  I had all you can eat sush.  Quality of fish w...       4
# 18743  I love sushi and when trying new places I am a...       9
# 18744  I'm going to state the obvious here: TYT has s...      25
# 18745  This place was not what I expected! The hype w...       3
# 18746  First time here and would come back. Clean res...       5
# 18747  Yes it's comparable to tacos el gordo but don'...       3
# 18748  The first time I came here I got really nervou...       0
# 18749  Bomb tacos honestly anything you get is really...       0
# 18750  It is a neat experience.  The ordering process...       0
# 18751  One of my favorite restaurants in town!\n\nI u...       1
# 18752  Great spot.  Good fun and super clean.  Stoped...       0
# 18753  Vegetarian tacos. That is all. \n\n\nJust kidd...       4
# 18754  Hubby was craving a late night snack. This pla...      11
# 18755  We needed a light lunch before attending an ea...       1
# 18756  I'm a big fan of this taco place.  If you come...       3
# 18757  Items Selected:\nTripas, Pibil, Carne Asada Ta...       3
# 18758  For Vegas standards, Taco y Taco is very authe...       1
# 18759  Wow, this is the real deal. Tried the carnitas...       1
# 18760  Let's taco about how much I like this place.  ...      14
# 18761  I was so excit d to try out this place... Cute...       0
# 18762  Just when I gave up hope for any good Mexican ...       2
# 18763  I've always driven passed their sign but final...       4
# 18764  A new crepe spot that just opened right on Dur...       2
#
#                       user_id  keep
# 0      _7PfR6Tvh2xTbiVi1GELoQ     1
# 1      LNPyE5X1K5B_flcTCH9StQ     1
# 2      D3fOi-5w4intrUTWXzIQew     1
# 3      JaqcCU3nxReTW2cBLHounA     1
# 4      NrpzAH3EoNhWUR8OysUhBQ     1
# 5      8e2KqFt1W67MA3ah09IYbw     1
# 6      3nIuSCZk5f_2WWYMLN7h3w     1
# 7      U4INQZOPSUaj8hMjLlZ3KA     1
# 8      s2o_JsABvrZVm_T03qrBUw     1
# 9      8e2KqFt1W67MA3ah09IYbw     1
# 10     AyjqBovADgbskmLrIBOMlQ     1
# 11     oeAhRa8yFa9jtrhaHnOyxQ     1
# 12     JaqcCU3nxReTW2cBLHounA     1
# 13     PKEzKWv_FktMm2mGPjwd0Q     1
# 14     QHX3NxFAlda3I32taYzI8w     1
# 15     oeAhRa8yFa9jtrhaHnOyxQ     1
# 16     U4INQZOPSUaj8hMjLlZ3KA     1
# 17     o9D90Dr6z27JL6AlivsoFw     1
# 18     LNPyE5X1K5B_flcTCH9StQ     1
# 19     JYcCYNWs8Ul6ewG5kCYW4Q     1
# 20     iSC96O2NjQc3JExGUHQG0Q     1
# 21     bHufZ2OTlC-OUxBDRXxViw     1
# 22     y5YNzZwQuYxgE-jSDcZLxA     1
# 23     I-4KVZ9lqHhk8469X9FvhA     1
# 24     eOIMO2wT_WbNqmavhnCRxw     1
# 25     VigsAph76fP7pechJ743EA     1
# 26     _7PfR6Tvh2xTbiVi1GELoQ     1
# 27     8fsZcLADFrPTbGrFqMACpg     1
# 28     vbG9-F7u-WUbY9lfvadIJw     1
# 29     JaqcCU3nxReTW2cBLHounA     1
# ...                       ...   ...
# 18735  B1829_hxXSEpDPEDJtYeIw     1
# 18736  lQBZo8_mm80dbwI5bo5c_w     1
# 18737  bHufZ2OTlC-OUxBDRXxViw     1
# 18738  CQZpblGIHeMlD7KqNP7J7Q     1
# 18739  OPJ0TW8tt5UanY2_YpCgIQ     1
# 18740  oqTZC9WriodTCby6jl0LfQ     1
# 18741  PQAR1z013WjtH6bMl5295A     1
# 18742  AsYBFmnMZMm9FOJi6o0seA     1
# 18743  zH6racrZ7rUqqv_Qy6dZDQ     1
# 18744  bLbSNkLggFnqwNNzzq-Ijw     1
# 18745  JB4_tH5U_oN7Xl3MA4aeHw     1
# 18746  WXDj6mmyrJi5q5nHKJ6H7w     1
# 18747  ukkRTJLkQTx95fCalVn6BA     1
# 18748  rYPjqZO89ABei1fsZBSUbA     1
# 18749  G2ToQ5eT91v2hkIT7I4X7g     1
# 18750  NrpzAH3EoNhWUR8OysUhBQ     1
# 18751  ImnJ5KKaWWNjj1E9kEArmQ     1
# 18752  sCelgwFoaNLMC_A7Y8usCw     1
# 18753  e3c6w6sM8sJ_g0IlF6CSog     1
# 18754  zQTEbn5nWGPypxOf2uRPmg     1
# 18755  L8P5OWO1Jh4B2HLa1Fnbng     1
# 18756  CQZpblGIHeMlD7KqNP7J7Q     1
# 18757  U4INQZOPSUaj8hMjLlZ3KA     1
# 18758  _pMzR6yoPbU98t-NH8TZ3w     1
# 18759  PQAR1z013WjtH6bMl5295A     1
# 18760  VigsAph76fP7pechJ743EA     1
# 18761  No5P-cOQQEf0Atgc9Vi84g     1
# 18762  B1829_hxXSEpDPEDJtYeIw     1
# 18763  wxQCLMnuVYbdtmQCc2ryZg     1
# 18764  w9WmBotuUdQlmuLa3XUkFQ     1
#
# [18765 rows x 15 columns]

# %% [markdown]
# #### Create utility matrix from records

# %%
# To be implemented
df_utility = pd.pivot_table(data=df_final, 
                            values='stars', 
                            index='user_id', 
                            columns='business_id', 
                            fill_value=0)

# %%
df_utility.shape
# Out:
# (193, 3297)

# %%
df_utility.head()
# Out:
# business_id             --9e1ONYQuAa-CB_Rrw7Tw  -1m9o3vGRA8IBPNvNqKLmA  \
# user_id
# -EJorVxe7h2GSxdiRyMmDA                       0                       0
# -xDW3gYiYaoeVASXywTPgw                       0                       0
# 06o1DmiBoiyxI2q3v2QRbg                       0                       0
# 0Md3sO3sRR3GE4eQLtqZbw                       0                       0
# 0hZfE2He1YssM_wEvKhfcA                       0                       0
#
# business_id             -3zffZUHoY8bQjGfPSoBKQ  -8R_-EkGpUhBk55K9Dd4mg  \
# user_id
# -EJorVxe7h2GSxdiRyMmDA                       0                       0
# -xDW3gYiYaoeVASXywTPgw                       0                       0
# 06o1DmiBoiyxI2q3v2QRbg                       0                       0
# 0Md3sO3sRR3GE4eQLtqZbw                       0                       0
# 0hZfE2He1YssM_wEvKhfcA                       0                       0
#
# business_id             -AD5PiuJHgdUcAK-Vxao2A  -ADtl9bLp8wNqYX1k3KuxA  \
# user_id
# -EJorVxe7h2GSxdiRyMmDA                       0                       0
# -xDW3gYiYaoeVASXywTPgw                       0                       4
# 06o1DmiBoiyxI2q3v2QRbg                       0                       0
# 0Md3sO3sRR3GE4eQLtqZbw                       0                       0
# 0hZfE2He1YssM_wEvKhfcA                       0                       0
#
# business_id             -Bf8BQ3yMk8U2f45r2DRKw  -BmqghX1sv7sgsxOIS2yAg  \
# user_id
# -EJorVxe7h2GSxdiRyMmDA                       0                       0
# -xDW3gYiYaoeVASXywTPgw                       0                       0
# 06o1DmiBoiyxI2q3v2QRbg                       0                       0
# 0Md3sO3sRR3GE4eQLtqZbw                       0                       0
# 0hZfE2He1YssM_wEvKhfcA                       0                       0
#
# business_id             -Bv-HHUs8aHzDrdWcZHn8w  -C8sSrFqaCxp51pyo-fQLQ  \
# user_id
# -EJorVxe7h2GSxdiRyMmDA                       0                       0
# -xDW3gYiYaoeVASXywTPgw                       0                       0
# 06o1DmiBoiyxI2q3v2QRbg                       0                       0
# 0Md3sO3sRR3GE4eQLtqZbw                       0                       0
# 0hZfE2He1YssM_wEvKhfcA                       0                       0
#
# business_id                      ...            zjvnqTjBp56NhMp1GrlO5g  \
# user_id                          ...
# -EJorVxe7h2GSxdiRyMmDA           ...                                 0
# -xDW3gYiYaoeVASXywTPgw           ...                                 0
# 06o1DmiBoiyxI2q3v2QRbg           ...                                 0
# 0Md3sO3sRR3GE4eQLtqZbw           ...                                 0
# 0hZfE2He1YssM_wEvKhfcA           ...                                 0
#
# business_id             zmltWmTpoBt5sCU-5Kzj-Q  znWHLW1pt19HzW1VY6KfCA  \
# user_id
# -EJorVxe7h2GSxdiRyMmDA                       0                       0
# -xDW3gYiYaoeVASXywTPgw                       3                       0
# 06o1DmiBoiyxI2q3v2QRbg                       0                       0
# 0Md3sO3sRR3GE4eQLtqZbw                       0                       0
# 0hZfE2He1YssM_wEvKhfcA                       0                       0
#
# business_id             zp-K5s3pGTWuuaVBWo6WZA  zpoZ6WyQUYff18-z4ZU1mA  \
# user_id
# -EJorVxe7h2GSxdiRyMmDA                       0                       4
# -xDW3gYiYaoeVASXywTPgw                       0                       0
# 06o1DmiBoiyxI2q3v2QRbg                       0                       0
# 0Md3sO3sRR3GE4eQLtqZbw                       0                       0
# 0hZfE2He1YssM_wEvKhfcA                       0                       0
#
# business_id             zr42_UsWfaIF-rcp37OpwA  zsQk990PubOHjr1YcLkQFw  \
# user_id
# -EJorVxe7h2GSxdiRyMmDA                       0                       0
# -xDW3gYiYaoeVASXywTPgw                       0                       0
# 06o1DmiBoiyxI2q3v2QRbg                       0                       0
# 0Md3sO3sRR3GE4eQLtqZbw                       0                       0
# 0hZfE2He1YssM_wEvKhfcA                       0                       0
#
# business_id             zuwba6QEBIDZT0tJZmNhdQ  zwNC-Ow4eIMan2__bS9-rg  \
# user_id
# -EJorVxe7h2GSxdiRyMmDA                       0                       0
# -xDW3gYiYaoeVASXywTPgw                       0                       0
# 06o1DmiBoiyxI2q3v2QRbg                       0                       0
# 0Md3sO3sRR3GE4eQLtqZbw                       0                       0
# 0hZfE2He1YssM_wEvKhfcA                       0                       0
#
# business_id             zx_j6OuuHHa2afVoAZuLpA
# user_id
# -EJorVxe7h2GSxdiRyMmDA                       0
# -xDW3gYiYaoeVASXywTPgw                       0
# 06o1DmiBoiyxI2q3v2QRbg                       0
# 0Md3sO3sRR3GE4eQLtqZbw                       0
# 0hZfE2He1YssM_wEvKhfcA                       0
#
# [5 rows x 3297 columns]

# %%
df_mat = df_utility.as_matrix()

# %%
df_mat.shape,df_utility.shape
# Out:
# ((193, 3297), (193, 3297))

# %%
from scipy import sparse
ratings_mat = sparse.csr_matrix(df_mat)

# %%
ratings_mat
# Out:
# <193x3297 sparse matrix of type '<type 'numpy.int64'>'
# 	with 18765 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## 2. Item-Item similarity recommender

# %% [markdown]
# ### Let's reuse the ItemItemRecommender class derived from previous exercise
#
# Hint: we need to make modification to accommodate the dense numpy array

# %%
# To be implemented
utility_mat = ratings_mat

# %%
# Item-Item Similarity Matrix
from sklearn.metrics.pairwise import cosine_similarity
item_sim_mat = cosine_similarity(utility_mat.T)

# %%
least_to_most_sim_indexes = np.argsort(item_sim_mat, axis=1)

# Neighborhoods
neighborhood_size = 75
neighborhoods = least_to_most_sim_indexes[:, -neighborhood_size:]

# %%
neighborhoods.shape
# Out:
# (3297, 75)

# %%
# Make a prediction for one lucky user
# Let's pick a lucky user
user_id = 99

# %%
from time import time
n_users = utility_mat.shape[0]
n_items = utility_mat.shape[1]

start_time = time()
items_rated_by_this_user = ratings_mat[user_id].nonzero()[1]
# Just initializing so we have somewhere to put rating preds
out = np.zeros(n_items)
for item_to_rate in range(n_items):
    relevant_items = np.intersect1d(neighborhoods[item_to_rate],
                                    items_rated_by_this_user,
                                    assume_unique=True)  # assume_unique speeds up intersection op
    out[item_to_rate] = ratings_mat[user_id, relevant_items] * \
        item_sim_mat[item_to_rate, relevant_items] / \
        item_sim_mat[item_to_rate, relevant_items].sum()


pred_ratings = np.nan_to_num(out)
print(pred_ratings)
print("Execution time: %f seconds" % (time()-start_time))
# Out:
# /Users/jieluo/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in divide
#   del sys.path[0]
# [4.         4.29995501 4.         ... 4.27821747 4.30668705 4.65757359]
# Execution time: 1.766231 seconds

# %%
# Get final recommendation
# Recommend n choices
n = 10

# Get item indexes sorted by predicted rating
item_index_sorted_by_pred_rating = list(np.argsort(pred_ratings))[::-1]

# Find items that have been rated by user
items_rated_by_this_user = ratings_mat[user_id].nonzero()[1]

# We want to exclude the items that have been rated by user
unrated_items_by_pred_rating = [item for item in item_index_sorted_by_pred_rating
                                if item not in items_rated_by_this_user]

unrated_items_by_pred_rating[:n]
# Out:
# [1608, 213, 2749, 2805, 2645, 2472, 870, 1704, 1187, 686]

# %%
business_id_lst = df_final['business_id'].unique()
business_id_dict = {k: v for v, k in enumerate(business_id_lst)}
df_final['business_id_map'] = df_final.apply(lambda x: business_id_dict[x['business_id']], axis=1)
# Out:
# /Users/jieluo/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
business_id_map_top_n = unrated_items_by_pred_rating[:n]
rec_business_name_lst = []
for id_map in business_id_map_top_n:
    #print id_map
    rec_business_name_lst.append(df_final[df_final['business_id_map'] == id_map]['name'].unique()[0])

rec_business_name_lst
# Out:
# ['Aloha Kitchen',
#  "Pt's Gold",
#  "Freed's Bakery",
#  'Tiabi Coffee & Waffle',
#  'The Westin Las Vegas Hotel & Spa',
#  'Burger King',
#  "Rocco's NY Pizzeria",
#  "Denny's",
#  'Yui Edomae Sushi',
#  "Tony Roma's"]

# %% [markdown]
# ## 3. Matrix Factorization recommender
#
# ##### Compare two of the methods demoed in Practice Class: sklearn NMF, sklearn TruncatedSVD, or GraphLab
# ##### *Extra points for using GraphLab

# %% [markdown]
# ##### NMF

# %%
from sklearn.decomposition import NMF

def fit_nmf(M,k):
    nmf = NMF(n_components=k)
    nmf.fit(M)
    W = nmf.transform(M);
    H = nmf.components_;
    err = nmf.reconstruction_err_
    return W,H,err

# decompose
W,H,err = fit_nmf(ratings_mat,169)
print(err)
print(W.shape,H.shape)
# Out:
# 136.2899470356833
# ((193, 169), (169, 3297))

# %%
# reconstruct
ratings_mat_fitted = W.dot(H)
errs = np.array((ratings_mat-ratings_mat_fitted).flatten()).squeeze()
mask = np.array((ratings_mat.todense()).flatten()).squeeze()>0

mse = np.mean(errs[mask]**2)
average_abs_err = abs(errs[mask]).mean()
print(mse)
print(average_abs_err)
# Out:
# 0.7096680222896242
# 0.30028216737130964

# %%
# get recommendations for one user
user_id = 99
n = 10

pred_ratings = ratings_mat_fitted[user_id,:]
item_index_sorted_by_pred_rating = list(np.argsort(pred_ratings))[::-1]

items_rated_by_this_user = ratings_mat[user_id].nonzero()[1]

unrated_items_by_pred_rating = [item for item in item_index_sorted_by_pred_rating
                                if item not in items_rated_by_this_user]

unrated_items_by_pred_rating[:n]
# Out:
# [193, 1209, 1713, 623, 499, 139, 2235, 1086, 1574, 3245]

# %%
business_id_map_top_n_NVM = unrated_items_by_pred_rating[:n]
rec_business_name_lst_NVM = []
for id_map in business_id_map_top_n_NVM:
    #print id_map
    rec_business_name_lst_NVM.append(df_final[df_final['business_id_map'] == id_map]['name'].unique()[0])

rec_business_name_lst_NVM
# Out:
# ['Pressed For Juice',
#  'Good Fella Korean Bistro',
#  'Sambalatte',
#  'Veggie House',
#  'Outback Steakhouse',
#  "Braddah's Island Style",
#  'Soho Sushi Burrito',
#  "Glazier's Food Marketplace",
#  'Greens and Proteins',
#  'Metro Diner']

# %%
### check errors
# truth
ratings_true = ratings_mat[user_id, items_rated_by_this_user].todense()
# prediction
ratings_pred = pred_ratings[items_rated_by_this_user]
print(list(zip(np.array(ratings_true).squeeze(),ratings_pred)))
err_one_user = ratings_true-ratings_pred
print(err_one_user)
print(abs(err_one_user).mean())
# Out:
# 0.01999705811425794

# %% [markdown]
# #####  UVD/SVD

# %%
from sklearn.decomposition import TruncatedSVD

def fit_uvd(M,k):
    # use TruncatedSVD to realize UVD
    svd = TruncatedSVD(n_components=k, n_iter=7, random_state=0)
    svd.fit(M)

    V = svd.components_
    U = svd.transform(M) # effectively, it's doing: U = M.dot(V.T)
    # we can ignore svd.singular_values_ for our purpose
    
    # why we can do this?
    # recall: 
    # SVD start from u*s*v=M => u*s=M*v.T, where M*v.T is our transformation above to get U in UVD
    # so the above U is effectively u*s in SVD
    # that's why U*V = u*s*v = M our original matrix
    # there are many ways to understand it!
    # here we by-passed singular values.
    
    return U,V, svd

# decompose
U,V,svd = fit_uvd(ratings_mat,169)

# %%
print(U.shape,V.shape)
# Out:
# ((193, 169), (169, 3297))

# %%
# reconstruct
ratings_mat_fitted = U.dot(V) # U*V


# recall: U = M.dot(V.T), then this is M.dot(V.T).dot(V)
# original M is transformed to new space, then transformed back
# this is another way to understand it!

# calculate errs
errs = np.array((ratings_mat-ratings_mat_fitted).flatten()).squeeze()
mask = np.array((ratings_mat.todense()).flatten()).squeeze()>0

mse = np.mean(errs[mask]**2)
average_abs_err = abs(errs[mask]).mean()
print(mse)
print(average_abs_err)
# Out:
# 0.157601336155406
# 0.2263427952674526

# %%
# compare with another way to reconstruct matrix
# with the above "tranformed to the new space and back" language
# without the UV language, we can do:

# reconstruct M with inverse_transform
ratings_mat_fitted_2 = svd.inverse_transform(svd.transform(ratings_mat))
ratings_mat_fitted = U.dot(V)
print(sum(sum(ratings_mat_fitted - ratings_mat_fitted_2)))
# they are just equivalent!!
# Out:
# 0.0

# %%
# get recommendations for one user
user_id = 100
n = 10

pred_ratings = ratings_mat_fitted[user_id,:]
item_index_sorted_by_pred_rating = list(np.argsort(pred_ratings))[::-1]

items_rated_by_this_user = ratings_mat[user_id].nonzero()[1]

unrated_items_by_pred_rating = [item for item in item_index_sorted_by_pred_rating
                                if item not in items_rated_by_this_user]

unrated_items_by_pred_rating[:n]
# Out:
# [1488, 2373, 1273, 1392, 1405, 2364, 2626, 2371, 2598, 324]

# %%
business_id_map_top_n_SVD = unrated_items_by_pred_rating[:n]
rec_business_name_lst_SVD = []
for id_map in business_id_map_top_n_SVD:
    #print id_map
    rec_business_name_lst_SVD.append(df_final[df_final['business_id_map'] == id_map]['name'].unique()[0])

rec_business_name_lst_SVD
# Out:
# ['Neighbors',
#  'Texas de Brazil',
#  'Me Gusta Tacos',
#  'Yum Cha',
#  'Chabuya',
#  'JINYA Ramen Bar',
#  'Mr Mamas',
#  'Thai BBQ',
#  'Eat.',
#  'Bacon Bar']

# %%
### check errors
# truth
ratings_true = ratings_mat[user_id, items_rated_by_this_user].todense()
# prediction
ratings_pred = pred_ratings[items_rated_by_this_user]
print(list(zip(np.array(ratings_true).squeeze(),ratings_pred)))
err_one_user = ratings_true-ratings_pred
print(err_one_user)
print(abs(err_one_user).mean())
# Out:
